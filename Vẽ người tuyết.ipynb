# %%
import turtle

h=turtle.Turtle()
h.pensize(1)
h.speed(5)
h.hideturtle()




h.circle(60,360)
h.right(90)
h.penup()
h.forward(180)
h.left(90)
h.pendown()
h.circle(90,360)
h.left(90)
h.penup()
h.forward(225)
h.pendown()
h.right(90)
h.fillcolor('orange')
h.begin_fill()
h.circle(8,360)
h.end_fill()
h.penup()
h.forward(30)
h.left(90)
h.forward(15)
h.right(90)
h.pendown()
h.fillcolor('black')
h.begin_fill()
h.circle(5,360)
h.end_fill()
h.penup()
h.backward(60)
h.pendown()
h.fillcolor('black')
h.begin_fill()
h.circle(5,360)
h.end_fill()
h.right(90)
h.penup()
h.forward(36)
h.left(90)
h.forward(15)
h.right(60)
h.pendown()
h.circle(20,120)

h.penup()
h.circle(20,300)
h.forward(60)
h.left(90)
h.forward(85)
h.left(90)
h.pendown()
h.pensize(20)
h.pencolor('orange')
h.forward(120)
h.penup()
h.backward(100)
h.right(90)
h.forward(20)
h.left(90)
h.pendown()
h.pensize(25)
h.forward(80)
h.left(90)
h.penup()
h.forward(120)
h.left(90)
h.pendown()
h.pencolor('red')
h.forward(80)
h.backward(25)
h.right(90)
h.forward(40)
h.pensize(1)
h.pencolor('green')
h.fillcolor('green')
h.penup()
h.right(90)
h.forward(20)
h.left(90)
h.forward(20)
h.left(90)
h.pendown()
h.begin_fill()
h.circle(5,360)
h.end_fill()
h.penup()
h.right(90)
h.forward(25)
h.left(90)
h.pendown()
h.begin_fill()
h.circle(5,360)
h.end_fill()
h.penup()
h.right(90)
h.forward(25)
h.left(90)
h.pendown()
h.begin_fill()
h.circle(5,360)
h.end_fill()
h.left(45)
h.penup()
h.forward(105)
h.pendown()
h.pencolor('black')
h.forward(80)
h.backward(20)
h.left(30)
h.forward(20)
h.backward(20)
h.right(60)
h.forward(20)
h.backward(20)
h.right(150)
h.forward(60)
h.right(40)
h.penup()
h.forward(152)
h.right(45)
h.pendown()
h.forward(80)
h.backward(20)
h.right(30)
h.forward(20)
h.backward(20)
h.left(60)
h.forward(20)




turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3288/853036556.py in <module>
#       1 import turtle
#       2
# ----> 3 h=turtle.Turtle()
#       4 h.pensize(1)
#       5 h.speed(5)
#
# ~\anaconda3\lib\turtle.py in __init__(self, shape, undobuffersize, visible)
#    3812         if Turtle._screen is None:
#    3813             Turtle._screen = Screen()
# -> 3814         RawTurtle.__init__(self, Turtle._screen,
#    3815                            shape=shape,
#    3816                            undobuffersize=undobuffersize,
#
# ~\anaconda3\lib\turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2556         self._undobuffersize = undobuffersize
#    2557         self.undobuffer = Tbuffer(undobuffersize)
# -> 2558         self._update()
#    2559
#    2560     def reset(self):
#
# ~\anaconda3\lib\turtle.py in _update(self)
# ...
